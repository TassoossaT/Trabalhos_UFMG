# %% [markdown]
# Connected to Python 3.11.9

# %%
from dea_compacto_Tasso import *
# dados de Provisão
data_prov.print()
# dados de Distribuição
data_dist.print()
# Out:
# +---------------------------+------+----------+----------+
# |            DMU            |  I1  |    I2    |    O1    |
# +---------------------------+------+----------+----------+
# |         Air Canada        | 2293 | 7217121  | 13028613 |
# |   ANA All Nippon Airways  | 2591 | 14651828 | 14683532 |
# |     American Airlines     | 1112 | 26310000 | 34707729 |
# |      British Airways      | 4624 | 19279420 | 21401581 |
# |      Delta Air Lines      | 6628 | 23357000 | 27292425 |
# |          Emirates         | 3457 | 20837627 | 27369447 |
# |      Garuda Indonesia     | 102  | 4736127  | 2834184  |
# |            KLM            | 4850 | 6706203  | 15090771 |
# |         Lufthansa         | 1979 | 31867956 | 27007957 |
# |     Malaysia Airlines     | 3762 | 3953020  | 7292543  |
# |           Qantas          | 6074 | 15118143 | 17368244 |
# | SAS Scandinavian Airlines | 2047 | 2954620  | 4152670  |
# |     Singapore Airlines    | 438  | 22323127 | 21286125 |
# ...

# %%
ccr_multiplicadores_input = Model_frabric_Weight(normatize_data(data_dist))
ccr_multiplicadores_output = Model_frabric_Weight(normatize_data(data_dist),mode="Output")
ccr_multiplicadores_input.model()
ccr_multiplicadores_output.model()
ccr_multiplicadores_input.print_solution(no_data=True)
ccr_multiplicadores_output.print_solution(no_data=True)
# Out:
# +---------------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# |            DMU            |         Ef         |       InvEf        |         u(0)        |         u(1)        |        u(2)        |         v(0)        |         v(1)        |
# +---------------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# |         Air Canada        | 0.9097995487352931 | 1.0991432138981536 |  0.8951323758536734 |  0.5087207528199654 |       1e-06        |  1.1694441556985409 |        1e-06        |
# |   ANA All Nippon Airways  | 0.7294380888491705 | 1.3709182661104156 |  1.853842352444113  |        1e-06        |       1e-06        |  1.4045294377302389 |        1e-06        |
# ...

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# +---------------------------+------------+----------------------+
# |            DMU            | Eficiência |    Classificação     |
# +---------------------------+------------+----------------------+
# |         Air Canada        |   90.93%   |     Ineficiente      |
# |   ANA All Nippon Airways  |   72.92%   |     Ineficiente      |
# |     American Airlines     |   92.65%   |     Ineficiente      |
# |      British Airways      |   90.91%   |     Ineficiente      |
# |      Delta Air Lines      |   98.69%   |     Ineficiente      |
# |          Emirates         |   97.78%   |     Ineficiente      |
# |      Garuda Indonesia     |   93.30%   |     Ineficiente      |
# |            KLM            |  100.00%   | Fracamente Eficiente |
# |         Lufthansa         |   94.32%   |     Ineficiente      |
# |     Malaysia Airlines     |   97.63%   |     Ineficiente      |
# |           Qantas          |  100.00%   | Fracamente Eficiente |
# ...

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(solution['efficiency'], edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:4
#       2 solution = ccr_multiplicadores_input.get_solution()
#       3 eficiencias = [dmu['efficiency'] for dmu in solution.values()]
# ----> 4 plt.hist(solution['efficiency'], edgecolor='black')
#       5 plt.xlabel('Eficiência')
#       6 plt.title('Histograma de Eficiências')
#
# KeyError: 'efficiency'

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(solution.values()['efficiency'], edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:4
#       2 solution = ccr_multiplicadores_input.get_solution()
#       3 eficiencias = [dmu['efficiency'] for dmu in solution.values()]
# ----> 4 plt.hist(solution.values()['efficiency'], edgecolor='black')
#       5 plt.xlabel('Eficiência')
#       6 plt.title('Histograma de Eficiências')
#
# TypeError: 'dict_values' object is not subscriptable

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()
plt.
import numpy as np

# Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
dmus = [dmu for dmu in self.solution.keys()]
eficiencias = [info['efficiency'] for info in self.solution.values()]

# Criar o histograma para determinar as faixas de eficiência
n, bins, _ = plt.hist(eficiencias, bins=30, alpha=0.5)

# Criar um gráfico de dispersão DMU/Eficiência
plt.figure()
for i, dmu in enumerate(dmus):
    # Encontrar a cor da barra do histograma onde a DMU se encaixa
    bin_index = np.digitize(eficiencias[i], bins) - 1
    plt.scatter(dmu, eficiencias[i], color=plt.cm.viridis(bin_index / len(bins)))

plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
#   Cell In[6], line 8
#     plt.
#         ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()
import numpy as np

# Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
dmus = [dmu for dmu in self.solution.keys()]
eficiencias = [info['efficiency'] for info in self.solution.values()]

# Criar o histograma para determinar as faixas de eficiência
n, bins, _ = plt.hist(eficiencias, bins=30, alpha=0.5)

# Criar um gráfico de dispersão DMU/Eficiência
plt.figure()
for i, dmu in enumerate(dmus):
    # Encontrar a cor da barra do histograma onde a DMU se encaixa
    bin_index = np.digitize(eficiencias[i], bins) - 1
    plt.scatter(dmu, eficiencias[i], color=plt.cm.viridis(bin_index / len(bins)))

plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:11
#       8 import numpy as np
#      10 # Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
# ---> 11 dmus = [dmu for dmu in self.solution.keys()]
#      12 eficiencias = [info['efficiency'] for info in self.solution.values()]
#      14 # Criar o histograma para determinar as faixas de eficiência
#
# NameError: name 'self' is not defined

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()
import numpy as np

# Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
dmus = [dmu for dmu in self.solution]
eficiencias = [info['efficiency'] for info in self.solution.values()]

# Criar o histograma para determinar as faixas de eficiência
n, bins, _ = plt.hist(eficiencias, bins=30, alpha=0.5)

# Criar um gráfico de dispersão DMU/Eficiência
plt.figure()
for i, dmu in enumerate(dmus):
    # Encontrar a cor da barra do histograma onde a DMU se encaixa
    bin_index = np.digitize(eficiencias[i], bins) - 1
    plt.scatter(dmu, eficiencias[i], color=plt.cm.viridis(bin_index / len(bins)))

plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:11
#       8 import numpy as np
#      10 # Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
# ---> 11 dmus = [dmu for dmu in self.solution]
#      12 eficiencias = [info['efficiency'] for info in self.solution.values()]
#      14 # Criar o histograma para determinar as faixas de eficiência
#
# NameError: name 'self' is not defined

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()
import numpy as np

# Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
dmus = [dmu['dmu_names'] for dmu in self.solution.values()]
eficiencias = [info['efficiency'] for info in self.solution.values()]

# Criar o histograma para determinar as faixas de eficiência
n, bins, _ = plt.hist(eficiencias, bins=30, alpha=0.5)

# Criar um gráfico de dispersão DMU/Eficiência
plt.figure()
for i, dmu in enumerate(dmus):
    # Encontrar a cor da barra do histograma onde a DMU se encaixa
    bin_index = np.digitize(eficiencias[i], bins) - 1
    plt.scatter(dmu, eficiencias[i], color=plt.cm.viridis(bin_index / len(bins)))

plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:11
#       8 import numpy as np
#      10 # Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
# ---> 11 dmus = [dmu['dmu_names'] for dmu in self.solution.values()]
#      12 eficiencias = [info['efficiency'] for info in self.solution.values()]
#      14 # Criar o histograma para determinar as faixas de eficiência
#
# NameError: name 'self' is not defined

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()
import numpy as np

# Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
dmus = [dmu['dmu_names'] for dmu in solution.values()]

# Criar o histograma para determinar as faixas de eficiência
n, bins, _ = plt.hist(eficiencias, bins=30, alpha=0.5)

# Criar um gráfico de dispersão DMU/Eficiência
plt.figure()
for i, dmu in enumerate(dmus):
    # Encontrar a cor da barra do histograma onde a DMU se encaixa
    bin_index = np.digitize(eficiencias[i], bins) - 1
    plt.scatter(dmu, eficiencias[i], color=plt.cm.viridis(bin_index / len(bins)))

plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:21
#      18 for i, dmu in enumerate(dmus):
#      19     # Encontrar a cor da barra do histograma onde a DMU se encaixa
#      20     bin_index = np.digitize(eficiencias[i], bins) - 1
# ---> 21     plt.scatter(dmu, eficiencias[i], color=plt.cm.viridis(bin_index / len(bins)))
#      23 plt.xlabel('DMU')
#      24 plt.ylabel('Eficiência')
#
# File c:\Users\tastc\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
#    3698 ) -> PathCollection:
# ...

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()
import numpy as np

# Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
dmus = [dmu['dmu_names'] for dmu in solution.values()]

# Criar o histograma para determinar as faixas de eficiência
n, bins, _ = plt.hist(eficiencias, alpha=0.5)

# Criar um gráfico de dispersão DMU/Eficiência
plt.figure()
for i, dmu in enumerate(dmus):
    # Encontrar a cor da barra do histograma onde a DMU se encaixa
    bin_index = np.digitize(eficiencias[i], bins) - 1
    plt.scatter(dmu, eficiencias[i], color=plt.cm.viridis(bin_index / len(bins)))

plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:21
#      18 for i, dmu in enumerate(dmus):
#      19     # Encontrar a cor da barra do histograma onde a DMU se encaixa
#      20     bin_index = np.digitize(eficiencias[i], bins) - 1
# ---> 21     plt.scatter(dmu, eficiencias[i], color=plt.cm.viridis(bin_index / len(bins)))
#      23 plt.xlabel('DMU')
#      24 plt.ylabel('Eficiência')
#
# File c:\Users\tastc\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
#    3698 ) -> PathCollection:
# ...

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()
import numpy as np

# Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
dmus = [dmu['dmu_names'] for dmu in solution.values()]

# Criar o histograma para determinar as faixas de eficiência

# Criar um gráfico de dispersão DMU/Eficiência
plt.figure()
for i, dmu in enumerate(dmus):
    # Encontrar a cor da barra do histograma onde a DMU se encaixa
    bin_index = np.digitize(eficiencias[i]) - 1
    plt.scatter(dmu, eficiencias[i])

plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:19
#      16 plt.figure()
#      17 for i, dmu in enumerate(dmus):
#      18     # Encontrar a cor da barra do histograma onde a DMU se encaixa
# ---> 19     bin_index = np.digitize(eficiencias[i]) - 1
#      20     plt.scatter(dmu, eficiencias[i])
#      22 plt.xlabel('DMU')
#
# TypeError: digitize() missing 1 required positional argument: 'bins'

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()
import numpy as np

# Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
dmus = [dmu['dmu_names'] for dmu in solution.values()]

# Criar o histograma para determinar as faixas de eficiência

# Criar um gráfico de dispersão DMU/Eficiência
plt.figure()
for i, dmu in enumerate(dmus):
    # Encontrar a cor da barra do histograma onde a DMU se encaixa
    bin_index = np.digitize(eficiencias[i]) - 1
    plt.scatter(dmu, eficiencias[i])

plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:19
#      16 plt.figure()
#      17 for i, dmu in enumerate(dmus):
#      18     # Encontrar a cor da barra do histograma onde a DMU se encaixa
# ---> 19     bin_index = np.digitize(eficiencias[i]) - 1
#      20     plt.scatter(dmu, eficiencias[i])
#      22 plt.xlabel('DMU')
#
# TypeError: digitize() missing 1 required positional argument: 'bins'

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()
import numpy as np

# Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
dmus = [dmu['dmu_names'] for dmu in solution.values()]

# Criar o histograma para determinar as faixas de eficiência

# Criar um gráfico de dispersão DMU/Eficiência
plt.figure()
for i, dmu in enumerate(dmus):
    # Encontrar a cor da barra do histograma onde a DMU se encaixa
    plt.scatter(dmu, eficiencias[i])

plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:19
#      16 plt.figure()
#      17 for i, dmu in enumerate(dmus):
#      18     # Encontrar a cor da barra do histograma onde a DMU se encaixa
# ---> 19     plt.scatter(dmu, eficiencias[i])
#      21 plt.xlabel('DMU')
#      22 plt.ylabel('Eficiência')
#
# File c:\Users\tastc\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
#    3698 ) -> PathCollection:
# -> 3699     __ret = gca().scatter(
#    3700         x,
#    3701         y,
# ...

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()
import numpy as np

# Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
dmus = [dmu['dmu_names'] for dmu in solution.values()]
plt.scatter(dmus, eficiencias)
# Criar o histograma para determinar as faixas de eficiência

# Criar um gráfico de dispersão DMU/Eficiência
plt.figure()

plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:12
#      10 # Supondo que 'self.solution' seja o seu dicionário com as DMUs e suas eficiências
#      11 dmus = [dmu['dmu_names'] for dmu in solution.values()]
# ---> 12 plt.scatter(dmus, eficiencias)
#      13 # Criar o histograma para determinar as faixas de eficiência
#      14
#      15 # Criar um gráfico de dispersão DMU/Eficiência
#      16 plt.figure()
#
# File c:\Users\tastc\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
# ...

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

dmus = [dmu['dmu_names'] for dmu in solution.values()]
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:10
#       7 plt.show()
#       9 dmus = [dmu['dmu_names'] for dmu in solution.values()]
# ---> 10 plt.scatter(dmus, eficiencias)
#      11 plt.figure()
#      12 plt.xlabel('DMU')
#
# File c:\Users\tastc\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
#    3698 ) -> PathCollection:
# -> 3699     __ret = gca().scatter(
#    3700         x,
#    3701         y,
#    3702         s=s,
#    3703         c=c,
#    3704         marker=marker,
# ...

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

dmus = [dmu['dmu_names'] for dmu in solution.values()]
print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# [DotMap(to_numpy=DotMap()), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap()]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:11
#       9 dmus = [dmu['dmu_names'] for dmu in solution.values()]
#      10 print(dmus)
# ---> 11 plt.scatter(dmus, eficiencias)
#      12 plt.figure()
#      13 plt.xlabel('DMU')
#
# File c:\Users\tastc\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
# ...

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

dmus = [dmu['dmu_names'] for dmu in solution]
print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:9
#       6 plt.title('Histograma de Eficiências')
#       7 plt.show()
# ----> 9 dmus = [dmu['dmu_names'] for dmu in solution]
#      10 print(dmus)
#      11 plt.scatter(dmus, eficiencias)
#
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:9
#       6 plt.title('Histograma de Eficiências')
#       7 plt.show()
# ----> 9 dmus = [dmu['dmu_names'] for dmu in solution]
#      10 print(dmus)
#      11 plt.scatter(dmus, eficiencias)
#
# TypeError: 'int' object is not subscriptable

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

dmus = [dmu['dmu_names'] for dmu in solution.items()]
print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:9
#       6 plt.title('Histograma de Eficiências')
#       7 plt.show()
# ----> 9 dmus = [dmu['dmu_names'] for dmu in solution.items()]
#      10 print(dmus)
#      11 plt.scatter(dmus, eficiencias)
#
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:9
#       6 plt.title('Histograma de Eficiências')
#       7 plt.show()
# ----> 9 dmus = [dmu['dmu_names'] for dmu in solution.items()]
#      10 print(dmus)
#      11 plt.scatter(dmus, eficiencias)
#
# TypeError: tuple indices must be integers or slices, not str

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

dmus = [dmu['dmu_names'] for dmu in solution.items()]
print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:9
#       6 plt.title('Histograma de Eficiências')
#       7 plt.show()
# ----> 9 dmus = [dmu['dmu_names'] for dmu in solution.items()]
#      10 print(dmus)
#      11 plt.scatter(dmus, eficiencias)
#
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:9
#       6 plt.title('Histograma de Eficiências')
#       7 plt.show()
# ----> 9 dmus = [dmu['dmu_names'] for dmu in solution.items()]
#      10 print(dmus)
#      11 plt.scatter(dmus, eficiencias)
#
# TypeError: tuple indices must be integers or slices, not str

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

dmus = [dmu['dmu_names'] for dmu in solution.items()]
print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:9
#       6 plt.title('Histograma de Eficiências')
#       7 plt.show()
# ----> 9 dmus = [dmu['dmu_names'] for dmu in solution.items()]
#      10 print(dmus)
#      11 plt.scatter(dmus, eficiencias)
#
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:9
#       6 plt.title('Histograma de Eficiências')
#       7 plt.show()
# ----> 9 dmus = [dmu['dmu_names'] for dmu in solution.items()]
#      10 print(dmus)
#      11 plt.scatter(dmus, eficiencias)
#
# TypeError: tuple indices must be integers or slices, not str

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

dmus = [dmu] for dmu in solution.items()]
print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
#   Cell In[22], line 9
#     dmus = [dmu] for dmu in solution.items()]
#                                             ^
# SyntaxError: unmatched ']'

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

dmus = [dmu] for dmu in solution.items()
print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
#   Cell In[23], line 9
#     dmus = [dmu] for dmu in solution.items()
#                  ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
eficiencias = [dmu['efficiency'] for dmu in solution.values()]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

dmus = dmu for dmu in solution.items()
print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
#   Cell In[24], line 9
#     dmus = dmu for dmu in solution.items()
#                ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
#eficiencias = [dmu['efficiency'] for dmu in solution.values()]
for dmu, sol in solution.items():
    eficiencias.append(sol.efficiency[dmu])
    dmu_name.append(sol.dmu_name[dmu])
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:5
#       3 #eficiencias = [dmu['efficiency'] for dmu in solution.values()]
#       4 for dmu, sol in solution.items():
# ----> 5     eficiencias.append(sol.efficiency[dmu])
#       6     dmu_name.append(sol.dmu_name[dmu])
#       7 plt.hist(eficiencias, edgecolor='black')
#
# TypeError: 'float' object is not subscriptable

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
#eficiencias = [dmu['efficiency'] for dmu in solution.values()]
for dmu, sol in solution.items():
    eficiencias +=[sol.efficiency[dmu]]
    dmu_name +=[sol.dmu_name[dmu]]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:5
#       3 #eficiencias = [dmu['efficiency'] for dmu in solution.values()]
#       4 for dmu, sol in solution.items():
# ----> 5     eficiencias +=[sol.efficiency[dmu]]
#       6     dmu_name +=[sol.dmu_name[dmu]]
#       7 plt.hist(eficiencias, edgecolor='black')
#
# TypeError: 'float' object is not subscriptable

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
#eficiencias = [dmu['efficiency'] for dmu in solution.values()]
for dmu, sol in solution.items():
    eficiencias +=[sol.efficiency]
    dmu_name +=[sol.dmu_name]
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:6
#       4 for dmu, sol in solution.items():
#       5     eficiencias +=[sol.efficiency]
# ----> 6     dmu_name +=[sol.dmu_name]
#       7 plt.hist(eficiencias, edgecolor='black')
#       8 plt.xlabel('Eficiência')
#
# NameError: name 'dmu_name' is not defined

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
#eficiencias = [dmu['efficiency'] for dmu in solution.values()]
for dmu, sol in solution.items():
    eficiencias +=sol.efficiency
    dmu +=sol.dmu_name
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:5
#       3 #eficiencias = [dmu['efficiency'] for dmu in solution.values()]
#       4 for dmu, sol in solution.items():
# ----> 5     eficiencias +=sol.efficiency
#       6     dmu +=sol.dmu_name
#       7 plt.hist(eficiencias, edgecolor='black')
#
# TypeError: 'float' object is not iterable

# %%
import matplotlib.pyplot as plt
solution = ccr_multiplicadores_input.get_solution()
#eficiencias = [dmu['efficiency'] for dmu in solution.values()]
for dmu, sol in solution.items():
    eficiencias =sol.efficiency
    dmu =sol.dmu_name
plt.hist(eficiencias, edgecolor='black')
plt.xlabel('Eficiência')
plt.title('Histograma de Eficiências')
plt.show()

print(dmus)
plt.scatter(dmus, eficiencias)
plt.figure()
plt.xlabel('DMU')
plt.ylabel('Eficiência')
plt.title('Gráfico de Eficiência por DMU')
plt.show()

Classificador_Eficiencia(data_dist).print()
# Out:
# [DotMap(to_numpy=DotMap(), getdoc=DotMap()), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap(), DotMap()]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\tastc\OneDrive\Área de Trabalho\Tps Otimização\Produtividade\Tp1\tp_01_dea.qmd:13
#      10 plt.show()
#      12 print(dmus)
# ---> 13 plt.scatter(dmus, eficiencias)
#      14 plt.figure()
#      15 plt.xlabel('DMU')
#
# File c:\Users\tastc\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
#    3698 ) -> PathCollection:
# ...
